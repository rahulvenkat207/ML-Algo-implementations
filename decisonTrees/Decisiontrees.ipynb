# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulvenkat207/ML-Algo-implementations/blob/main/decisonTrees/Decisiontrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("salaries.csv")
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
inputs = df.drop('salary_more_then_100k',axis='columns')
target = df['salary_more_then_100k']

# %%
inputs.head()
# Out:
#   company                  job     degree
# 0  google      sales executive  bachelors
# 1  google      sales executive    masters
# 2  google     business manager  bachelors
# 3  google     business manager    masters
# 4  google  computer programmer  bachelors

# %%
target.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: salary_more_then_100k, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_company = LabelEncoder()
le_job= LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_num'] = le_company.fit_transform(inputs['company'])
inputs['job_num'] = le_job.fit_transform(inputs['job'])
inputs['degree_num'] = le_degree.fit_transform(inputs['degree'])
inputs.head()
# Out:
#   company                  job     degree  company_num  job_num  degree_num
# 0  google      sales executive  bachelors            2        2           0
# 1  google      sales executive    masters            2        2           1
# 2  google     business manager  bachelors            2        0           0
# 3  google     business manager    masters            2        0           1
# 4  google  computer programmer  bachelors            2        1           0

# %%
inputs_n = inputs.drop(['company','job','degree'],axis = 'columns')
inputs_n.head()
# Out:
#    company_num  job_num  degree_num
# 0            2        2           0
# 1            2        2           1
# 2            2        0           0
# 3            2        0           1
# 4            2        1           0

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 1.0

# %%
model.predict([[2,2,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[2,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# # Exercise

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
input = df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked','Survived'],axis ='columns')
input.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
target = df['Survived']
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
le_sex = LabelEncoder()
input['sex_num'] = le_sex.fit_transform(input['Sex'])
input.head()
# Out:
#    Pclass     Sex   Age     Fare  sex_num
# 0       3    male  22.0   7.2500        1
# 1       1  female  38.0  71.2833        0
# 2       3  female  26.0   7.9250        0
# 3       1  female  35.0  53.1000        0
# 4       3    male  35.0   8.0500        1

# %%
new_input = input.drop('Sex',axis = 'columns')
new_input.head()
# Out:
#    Pclass   Age     Fare  sex_num
# 0       3  22.0   7.2500        1
# 1       1  38.0  71.2833        0
# 2       3  26.0   7.9250        0
# 3       1  35.0  53.1000        0
# 4       3  35.0   8.0500        1

# %%
new_input['Age'] = new_input.Age.fillna(input.Age.mean())

# %%
new_input.Age[:10]
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %%
new_model = tree.DecisionTreeClassifier()

# %%
new_model.fit(new_input,target)
# Out:
# DecisionTreeClassifier()

# %%
new_model.score(new_input,target)
# Out:
# 0.9797979797979798
