# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulvenkat207/ML-Algo-implementations/blob/main/Gradient-Descent/gradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
from sklearn import linear_model

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000
  n = len(x)
  n1 = 2*n
  learning_rate =0.001
  cost_previous = 0
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = (1/n1) * sum(val**2 for val in(y - y_predicted))
    md = - (1/n) * sum(x*(y - y_predicted))
    bd = - (1/n) * sum(y - y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
    cost_previous = cost
    print(f"Iteration: {i}->m = {m_curr}, b = {b_curr}, cost= {cost}")
  return m_curr ,b_curr

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# Iteration: 0->m = 0.031, b = 0.009000000000000001, cost= 44.5
# Iteration: 1->m = 0.061632000000000006, b = 0.017898000000000004, cost= 43.464163000000006
# Iteration: 2->m = 0.09190035400000002, b = 0.026695206000000006, cost= 42.452687206642
# Iteration: 3->m = 0.12180936448800002, b = 0.035392809732000007, cost= 41.46499959851549
# Iteration: 4->m = 0.15136328304943603, b = 0.04399198882880401, cost= 40.5005406327804
# Iteration: 5->m = 0.1805663109694058, b = 0.05249390699082689, cost= 39.55876392812508
# Iteration: 6->m = 0.20942259982776987, b = 0.06089971415092785, cost= 38.63913595518173
# Iteration: 7->m = 0.2379362520872116, b = 0.0692105466372936, cost= 37.7411357342238
# Iteration: 8->m = 0.26611132167434043, b = 0.07742752733439467, cost= 36.86425453997426
# Iteration: 9->m = 0.2939518145539195, b = 0.08555176584203726, cost= 36.0079956133572
# Iteration: 10->m = 0.32146168929630026, b = 0.09358435863253346, cost= 35.17187388002966
# ...

# %% [markdown]
# # Exercise

# %%
import pandas as pd
df = pd.read_csv("test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
def linear_regression_model():
  df = pd.read_csv("test_scores.csv")
  reg = linear_model.LinearRegression()
  reg.fit(df[['math']],df.cs)
  return reg.coef_,reg.intercept_

# %%
m, b = gradient_descent(x,y)
print("Using gradient descent function: Coef {} Intercept {}".format(m, b))
m_sklearn, b_sklearn = linear_regression_model()
print("Using sklearn: Coef {} Intercept {}".format(m_sklearn,b_sklearn))
# Out:
# Iteration: 0->m = 0.031, b = 0.009000000000000001, cost= 44.5
# Iteration: 1->m = 0.061632000000000006, b = 0.017898000000000004, cost= 43.464163000000006
# Iteration: 2->m = 0.09190035400000002, b = 0.026695206000000006, cost= 42.452687206642
# Iteration: 3->m = 0.12180936448800002, b = 0.035392809732000007, cost= 41.46499959851549
# Iteration: 4->m = 0.15136328304943603, b = 0.04399198882880401, cost= 40.5005406327804
# Iteration: 5->m = 0.1805663109694058, b = 0.05249390699082689, cost= 39.55876392812508
# Iteration: 6->m = 0.20942259982776987, b = 0.06089971415092785, cost= 38.63913595518173
# Iteration: 7->m = 0.2379362520872116, b = 0.0692105466372936, cost= 37.7411357342238
# Iteration: 8->m = 0.26611132167434043, b = 0.07742752733439467, cost= 36.86425453997426
# Iteration: 9->m = 0.2939518145539195, b = 0.08555176584203726, cost= 36.0079956133572
# Iteration: 10->m = 0.32146168929630026, b = 0.09358435863253346, cost= 35.17187388002966
# ...
